# %% [markdown]
# # Phyiscs Problems - Lectures 18 & 19 - Homework 9
#
# FALL 2023

# %% [markdown]
# ### 1) Altitude of a satellite
#
# A satellite is to be launched into a circular orbit around the Earth so that it orbits the planet once every T seconds.
#
# The altitude h above the Earth’s surface that the satellite must have is:
#
# $$h = \left( \frac{G M T^2}{4\pi^2} \right)^{1/3} - R$$
#
# where $G = 6.67 \times 10^{-11}$ m$^3$ kg$^{-1}$ s$^{-2}$
# is Newton's gravitational constant, $M = 5.97 \times 10^{24}$ kg is the mass of the Earth, and $R = 6371$ km is its radius.
#
# #### Write a program that asks the user to enter the desired value of T and then calculates and prints out the correct altitude in meters.

# %%
import math

T = int(input("Input your T value in minutes: "))
inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T/60)**2)))/(4*(math.pi)**2)
h = inside**(1/3) - (6371*1000)
if T > 0:
    print(h)
# Out:
# Input your T value in minutes: 45
# -6353164.40296247

# %% [markdown]
# Use your program to calculate the altitudes of satellites that orbit the Earth once
# a day (so-called “geosynchronous” orbit), once every 90 minutes, and once every
# 45 minutes. What do you conclude from the last of these calculations?

# %%
import math

T = int(input("Input your T value in minutes: "))
inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T*60)**2)))/(4*(math.pi)**2)
h = inside**(1/3) - (6371*1000)
if T > 0:
    print(h)
# Out:
# Input your T value in minutes: 90
# 279321.62537285965

# %%
import math

T = int(input("Input your T value in minutes: "))
inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T*60)**2)))/(4*(math.pi)**2)
h = inside**(1/3) - (6371*1000)
if T > 0:
    print(h)
# Out:
# Input your T value in minutes: 1440
# 35855910.17617497

# %% [markdown]
# Technically a geosynchronous satellite is one that orbits the Earth once persidereal
# day, which is 23.93 hours, not 24 hours. Why is this? And how much difference
# will it make to the altitude of the satellite?

# %%
#this is the case because a a sidereal day is not a solar day meaning it is the time it takes for a point on a planet
#to face a particular star again (day according to stars) depending on orbital motion of the planet

T = int(input("Input your T value in hours: "))
inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T*3600)**2)))/(4*(math.pi)**2)
h = inside**(1/3) - (6371*1000)
if T > 0:
    print(h)
# Out:
# Input your T value in hours: 24
# 35855910.17617497

# %%
T = float(input("Input your T value in minutes: "))
inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T*3600)**2)))/(4*(math.pi)**2)
h = inside**(1/3) - (6371*1000)
if T > 0:
    print(h)
# Out:
# Input your T value in minutes: 23.93
# 35773762.329895645

# %%
difference = 35855910.17617497 - 35773762.329895645
print("The difference between orbits of 24 hours and 23.93 hours is " + str(difference))
# Out:
# The difference between orbits of 24 hours and 23.93 hours is 82147.8462793231

# %% [markdown]
# #### Modify your code to calculate the times from 0.5 hour  to 30 days, in steps of 0.5 hours.   Then plot those data points (time vs h) with properly labled axes.  Plot orbits with height below 0 as red, and plots positive heeghts with times less than geosynchronous in blue and those longer in green.

# %%
import numpy as np
from matplotlib import pyplot as plt

Treal = []
hreal = []
for T in range(30,43200,30):
    inside = (((6.67*(10**(-11))*(5.97*(10**24))*(T*60)**2)))/(4*(np.pi)**2)
    h = inside**(1/3) - (6371*1000)
    Treal = np.append(Treal,T)
    hreal = np.append(hreal,h)

fig1 = plt.figure(figsize=(20,10))
ax1 = fig1.add_subplot(111)
ax1.plot(Treal, hreal,c='b')
hrealbelow = hreal < 0  #stores negative hreal values
hrealmid = (hreal > 0) & (Treal < 24*60) #stores positive hreal values less than a geosynchronous orbit
ax1.plot(Treal[hrealmid], hreal[hrealmid],c='g')
ax1.plot(Treal[hrealbelow], hreal[hrealbelow],c='r')
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

ax1.set_xlabel("time in hours",size=20)
ax1.set_ylabel("height in meters",size=20)
# Out:
# Text(0, 0.5, 'height in meters')

# %% [markdown]
# ### 2) Special Relativity
#
# A spaceship travels from Earth in a straight line at a (relativistic)
# speed $v$ to another planet $x$ light years away. Write a program to ask
# the user for the value of $x$ and the speed $v$ as a fraction of the speed
# of light, then print out the time in years that the spaceship takes to
# reach its destination (a) in the rest frame of an observer on Earth
# and (b) as perceived by a passenger on board the ship.
#
# $$x' = \gamma (x - vt)$$
#
# $$t' = \gamma \left(t - \frac{v x}{c^2}\right)$$
#
# $$\gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2}}}$$

# %%
import math

x = int(input("Input number of light years planet is away from Earth: "))
v = float(input("Input the relativistic speed v of the spacesheep as a fraction or decimal of the speed of light c: "))
gamma = 1/math.sqrt(1-v)
tregular = x/v
#a
tEarth = gamma*(tregular - (v*x)/(3.00*(10**8))**2)
#b
tpassenger = tregular
print("Time in years for passenger in spaceship is " + str(tpassenger) + " years")
print("Time in years for observer on Earth is " + str(tEarth) + " years")
# Out:
# Input number of light years planet is away from Earth: 10
# Input the relativistic speed v of the spacesheep as a fraction or decimal of the speed of light c: .4
# Time in years for passenger in spaceship is 25.0 years
# Time in years for observer on Earth is 32.27486121839514 years

# %% [markdown]
# #### Use your program to calculate the answers for a planet 10 light years away with $v = 0.90c$,  $v = 0.98c$, $v = 0.999c$.

# %%
#for v = 0.90c
import math

x = int(input("Input number of light years planet is away from Earth: "))
v = 0.90
gamma = 1/math.sqrt(1-v)
tregular = x/v
#a
tEarth = gamma*(tregular - (v*x)/(3.00*(10**8))**2)
#b
tpassenger = tregular
print("Time in years for passenger in spaceship is " + str(tpassenger) + " years")
print("Time in years for observer on Earth is " + str(tEarth) + " years")
# Out:
# Input number of light years planet is away from Earth: 10
# Time in years for passenger in spaceship is 11.11111111111111 years
# Time in years for observer on Earth is 35.13641844631533 years

# %%
#for v = 0.98c
import math

x = int(input("Input number of light years planet is away from Earth: "))
v = 0.98
gamma = 1/math.sqrt(1-v)
tregular = x/v
#a
tEarth = gamma*(tregular - (v*x)/(3.00*(10**8))**2)
#b
tpassenger = tregular
print("Time in years for passenger in spaceship is " + str(tpassenger) + " years")
print("Time in years for observer on Earth is " + str(tEarth) + " years")
# Out:
# Input number of light years planet is away from Earth: 10
# Time in years for passenger in spaceship is 10.204081632653061 years
# Time in years for observer on Earth is 72.15375318230075 years

# %%
#for v = 0.999c
import math

x = int(input("Input number of light years planet is away from Earth: "))
v = 0.999
gamma = 1/math.sqrt(1-v)
tregular = x/v
#a
tEarth = gamma*(tregular - (v*x)/(3.00*(10**8))**2)
#b
tpassenger = tregular
print("Time in years for passenger in spaceship is " + str(tpassenger) + " years")
print("Time in years for observer on Earth is " + str(tEarth) + " years")
# Out:
# Input number of light years planet is away from Earth: 10
# Time in years for passenger in spaceship is 10.01001001001001 years
# Time in years for observer on Earth is 316.54431032716496 years

# %% [markdown]
# ### 3) The quadratic equation
#
#  Write a program that takes as input three numbers, $a$, $b$, and $c$, and prints out the two solutions to the quadratic equation $ax^2 + bx + c = 0$ using the standard
# formula:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# Use your program to compute the solutions of $0.001x^2 + 1000x + 0.001 = 0$.

# %%
import math

a = float(input("Input any number: "))
b = float(input("Input any number: "))
c = float(input("Input any number: "))
x1 = (-b + math.sqrt((b**2)-4*(a)*(c)))/(2*a)
x2 = (-b - math.sqrt((b**2)-4*(a)*(c)))/(2*a)
print("Solution 1 is " + str(x1))
print("Solution 2 is " + str(x2))
# Out:
# Input any number: 0.001
# Input any number: 1000
# Input any number: 0.001
# Solution 1 is -9.999894245993346e-07
# Solution 2 is -999999.999999

# %% [markdown]
# There is another way to write the solutions to a quadratic equation. Multiplying top and bottom of the solution above by $-b \mp \sqrt{b^2 - 4ac}$, show that the solutions
# can also be written as:
#
# $$x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}$$
#
# Add further lines to your program to print these values in addition to the earlier ones and again use the program to solve $0.001x^2 + 1000x + 0.001 = 0$. What do you see? How do you explain it?

# %%
import math

a = float(input("Input any number: "))
b = float(input("Input any number: "))
c = float(input("Input any number: "))
x1 = 2*c/(-b + math.sqrt((b**2)-4*(a)*(c)))
x2 = 2*c/(-b - math.sqrt((b**2)-4*(a)*(c)))
print("Solution 1 is " + str(x1))
print("Solution 2 is " + str(x2))

#In both cases, solution 2 is the correct solution for our case. This is the case because python finds it really hard to 
#calculate really small numbers. 4ac is so small that the number under the square root essentially become "b". As such,
#in terms of magnitude, doing -b - "b" would be larger and more palatable for python than doing -b + "b".
# Out:
# Input any number: 0.001
# Input any number: 1000
# Input any number: 0.001
# Solution 1 is -1000010.5755125057
# Solution 2 is -1.000000000001e-06

# %% [markdown]
# Using what you have learned, write a new program that calculates both roots of a quadratic equation accurately in all cases.

# %% [markdown]
# # 4) Planetary orbits
#
# The orbit in space of one body around another, such as a planet around the Sun, need not be circular. In general it takes the form of an ellipse, with the body sometimes closer in and sometimes further out. If you are given the distance $l_1$ of closest approach that a planet makes to the Sun, also called its perihelion, and its linear velocity $v_1$ at *perihelion*, then any other property of the orbit can be calculated from these two as follows.
#
# Kepler’s second law tells us that the distance $l_2$ and velocity $v_2$ of the planet at its most distant point, or *aphelion*, satisfy $l_2 v_2 = l_1 v_1$.
#
#
# Given the values of $v_1$, $l_1$, and $l_2$, other parameters of the orbit are given by simple formulas can that be derived from Kepler’s laws and the fact that the orbit is an ellipse:
#
# Semi-Major Axis $$ a = \frac{1}{2} (l_1 + l_2) $$
# Semi-Minor Axis: $$ b = \sqrt{l_1  l_2} $$
# Orbital Period: $$ T = \frac{2 \pi a b}{l_1 v_1} $$
# Orbital eccentricity:  $$ e = \frac{l_2 - l_1}{l_2 + l_1}$$
#
# #### Write a program with functions that asks the user to enter the distance to the Sun and velocity at perihelion, then calculates and prints the quantities $l2$, $v2$, $a$, $b$, $T$, and $e$.

# %%
#v2 equation: v2**2 -2*G*M/v1*l1*(v2) - ((v1**2)- 2*G*M/l1)  Note: quad equation solver, knows middle v2 is there
import math

l1 = float(input("Input distance to Sun and velocity at perihelion: "))
v1 = float(input("Input velocity at perihelion: "))
G = 6.67*(10**-11)
M = 1.9891e30
bq = (-2*G*M)/(v1*l1)
c = -(v1**2 - (2*G*M)/l1)
a = 1
v2 = (-bq - math.sqrt((bq**2)-4*(a)*(c)))/(2*a) #Solves quadratic equation using variables bq and c which represent parts of the equation for v2
l2 = (l1*v1)/v2

#Semi major Axis
a = (1/2)*(l1+l2)
#Semi minor axis
b = math.sqrt(l1*l2)
#Orbital Period
T = (2*(math.pi)*a*b)/(l1*v1)
#Orbital Eccentricity
e = (l2-l1)/(l2+l1)

print("velocity at apehelion is: " + str(v2))
print("distance at apehelion is: " + str(l2))
print("semi major axis is: " + str(a))
print("semi minor axis is: " + str(b))
print("orbital period is: " + str(T))
print("orbital eccentricity is: " + str(e))

# %% [markdown]
# #### Test your program by having it calculate the properties of the orbits of the Earth (for which $l_1 = 1.4710 \times 10^{11}$ m and $v_1 = 3.0287 \times 10^4$ m s$^{−1}$ ) and Halley’s comet ($l_1 = 8.7830 \times 10^{10}$ m and $v_1 = 5.4529 \times 10^4$ m s${−1}$ ). Among other things, you should find that the orbital period of the Earth is one year and that of Halley’s comet is about 76 years.

# %%
#v2 equation: v2**2 -2*G*M/v1*l1*(v2) - ((v1**2)- 2*G*M/l1)  Note: quad equation solver, knows middle v2 is there
import math

l1 = float(input("Input distance to Sun and velocity at perihelion: "))
v1 = float(input("Input velocity at perihelion: "))
G = 6.67*(10**-11)
M = 1.9891e30
bq = (-2*G*M)/(v1*l1)
c = -(v1**2 - (2*G*M)/l1)
a = 1
v2 = (-bq - math.sqrt((bq**2)-4*(a)*(c)))/(2*a)
#Solves quadratic equation using variables bq and c which represent parts of the equation for v2
l2 = (l1*v1)/v2
print(l2)

#Semi major Axis
a = (1/2)*(l1+l2)
#Semi minor axis
b = math.sqrt(l1*l2)
#Orbital Period
T = (2*(math.pi)*a*b)/(l1*v1)
#Orbital Eccentricity
e = (l2-l1)/(l2+l1)

print("velocity at apehelion is: " + str(v2))
print("distance at apehelion is: " + str(l2))
print("semi major axis is: " + str(a))
print("semi minor axis is: " + str(b))
print("orbital period is: " + str(T))
print("orbital eccentricity is: " + str(e))
# Out:
# Input distance to Sun and velocity at perihelion: 1.4710e11
# Input velocity at perihelion: 3.0287e4
# 152203426488.95538
# velocity at apehelion is: 29271.467816286593
# distance at apehelion is: 152203426488.95538
# semi major axis is: 149651713244.4777
# semi minor axis is: 149629957015.71707
# orbital period is: 31579931.406081557
# orbital eccentricity is: 0.017051012575506567
